# %%
from pathlib import Path
from cleaning import build_clean_model_df, find_project_root

project_root = find_project_root()
master = project_root / "data" / "procesed" / "master_2019_1M_per_month.parquet"
zones  = project_root / "data" / "raw" / "taxi_zone_lookup.csv"

df_model = build_clean_model_df(master, zones)
df_model.head()
# Out:
#    DOLocationID  PULocationID  RatecodeID  VendorID  extra  fare_amount  \
# 0           234           164         1.0       2.0    0.0          4.5
# 1           230           100         1.0       2.0    0.0          7.0
# 2           162           140         1.0       2.0    1.0         10.5
# 3           239           151         1.0       1.0    0.0          5.5
# 4           260           140         1.0       1.0    0.0         20.0
#
#    improvement_surcharge  mta_tax  passenger_count  payment_type  ...  \
# 0                    0.3      0.5              1.0           1.0  ...
# 1                    0.3      0.5              1.0           1.0  ...
# 2                    0.3      0.5              1.0           2.0  ...
# 3                    0.3      0.5              1.0           1.0  ...
# 4                    0.3      0.5              1.0           1.0  ...
#
#        hour_cos  month_sin  month_cos  PU_Borough DO_Borough log_duration  \
# ...
